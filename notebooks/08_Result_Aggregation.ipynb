# %% [markdown]
# # Unified Model Results Aggregation
#
# This notebook aggregates evaluation results from all trained models across previous notebooks into a single comparison table. No models are trained or modified in this notebook.

# %% [markdown]
# ## Import Required Libraries

# %%
import os
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Results Directory Overview
#
# All model evaluation outputs are stored in the `results/` directory. Each model has its own subfolder containing metrics.

# %%
RESULTS_DIR = "../results"

model_folders = [
    f for f in os.listdir(RESULTS_DIR)
    if os.path.isdir(os.path.join(RESULTS_DIR, f))
]

model_folders
# Out:
# ['adaboost',
#  'extra_trees',
#  'gaussian_process',
#  'gradient_boosting',
#  'k_nearest_neighbors',
#  'logistic_regression',
#  'mlp_neural_network',
#  'naive_bayes',
#  'random_forest',
#  'ridge_classifier',
#  'svm_rbf']

# %% [markdown]
# ## Metric Extraction Utility
#
# This function extracts key evaluation metrics from each model’s results.

# %%
def extract_model_results(model_name):
    model_path = os.path.join(RESULTS_DIR, model_name)

    # Load classification report
    report_path = os.path.join(model_path, "classification_report.json")
    with open(report_path, "r") as f:
        report = json.load(f)

    # Extract macro-averaged metrics
    precision = report["macro avg"]["precision"]
    recall = report["macro avg"]["recall"]
    f1 = report["macro avg"]["f1-score"]
    accuracy = report["accuracy"]

    # Load ROC-AUC if available
    roc_auc_path = os.path.join(model_path, "roc_auc.txt")
    if os.path.exists(roc_auc_path):
        with open(roc_auc_path, "r") as f:
            roc_auc = float(f.read())
    else:
        roc_auc = np.nan

    return {
        "Model": model_name.replace("_", " ").title(),
        "Accuracy": round(accuracy, 3),
        "Precision (Macro)": round(precision, 3),
        "Recall (Macro)": round(recall, 3),
        "F1-score (Macro)": round(f1, 3),
        "ROC-AUC": round(roc_auc, 3) if not np.isnan(roc_auc) else "N/A"
    }

# %% [markdown]
# ## Aggregate Results from All Models

# %%
results = []

for model in model_folders:
    try:
        results.append(extract_model_results(model))
    except Exception as e:
        print(f"Skipping {model}: {e}")

results_df = pd.DataFrame(results)
results_df
# Out:
#                   Model  Accuracy  Precision (Macro)  Recall (Macro)  \
# 0              Adaboost     0.899              0.866           0.866
# 1           Extra Trees     0.913              0.884           0.884
# 2      Gaussian Process     0.892              0.857           0.856
# 3     Gradient Boosting     0.913              0.884           0.883
# 4   K Nearest Neighbors     0.615              0.539           0.552
# 5   Logistic Regression     0.899              0.865           0.869
# 6    Mlp Neural Network     0.514              0.451           0.490
# 7           Naive Bayes     0.319              0.451           0.396
# 8         Random Forest     0.912              0.883           0.881
# 9      Ridge Classifier     0.871              0.832           0.832
# 10              Svm Rbf     0.240              0.080           0.333
#
#     F1-score (Macro) ROC-AUC
# 0              0.865   0.956
# 1              0.884   0.979
# 2              0.857   0.972
# 3              0.884   0.979
# 4              0.543   0.747
# 5              0.867   0.972
# 6              0.430   0.673
# 7              0.262   0.716
# 8              0.882   0.978
# 9              0.829     N/A
# 10             0.129   0.704

# %% [markdown]
# ## Sort Models by ROC-AUC

# %%
# Convert ROC-AUC column to numeric (coerce non-numeric values to NaN)
results_df["ROC-AUC"] = pd.to_numeric(
    results_df["ROC-AUC"],
    errors="coerce"
)

# %%
results_df_sorted = results_df.sort_values(
    by="ROC-AUC",
    ascending=False,
    na_position="last"
).reset_index(drop=True)

results_df_sorted
# Out:
#                   Model  Accuracy  Precision (Macro)  Recall (Macro)  \
# 0           Extra Trees     0.913              0.884           0.884
# 1     Gradient Boosting     0.913              0.884           0.883
# 2         Random Forest     0.912              0.883           0.881
# 3   Logistic Regression     0.899              0.865           0.869
# 4      Gaussian Process     0.892              0.857           0.856
# 5              Adaboost     0.899              0.866           0.866
# 6   K Nearest Neighbors     0.615              0.539           0.552
# 7           Naive Bayes     0.319              0.451           0.396
# 8               Svm Rbf     0.240              0.080           0.333
# 9    Mlp Neural Network     0.514              0.451           0.490
# 10     Ridge Classifier     0.871              0.832           0.832
#
#     F1-score (Macro)  ROC-AUC
# 0              0.884    0.979
# 1              0.884    0.979
# 2              0.882    0.978
# 3              0.867    0.972
# 4              0.857    0.972
# 5              0.865    0.956
# 6              0.543    0.747
# 7              0.262    0.716
# 8              0.129    0.704
# 9              0.430    0.673
# 10             0.829      NaN

# %% [markdown]
# ## Save Unified Results Table

# %%
OUTPUT_PATH = "../reports/unified_model_results.csv"
os.makedirs("../reports", exist_ok=True)

results_df_sorted.to_csv(OUTPUT_PATH, index=False)

print(f"Unified results table saved to {OUTPUT_PATH}")
# Out:
# Unified results table saved to ../reports/unified_model_results.csv
